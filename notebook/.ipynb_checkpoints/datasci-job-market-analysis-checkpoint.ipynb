# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('seaborn')

# %%
path = ''
da = pd.read_csv(path+'DataAnalyst.csv')
de = pd.read_csv(path+'DataEngineer.csv')
ds = pd.read_csv(path+'DataScientist.csv')
data = pd.concat([da, de, ds])

# %%
data = data.drop(columns=['index', 'Unnamed: 0'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8690 entries, 0 to 3908
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          8690 non-null   object
#  1   Salary Estimate    8690 non-null   object
#  2   Job Description    8690 non-null   object
#  3   Rating             8690 non-null   float64
#  4   Company Name       8689 non-null   object
#  5   Location           8690 non-null   object
#  6   Headquarters       8690 non-null   object
#  7   Size               8690 non-null   object
#  8   Founded            8690 non-null   int64
#  9   Type of ownership  8690 non-null   object
#  10  Industry           8690 non-null   object
#  11  Sector             8690 non-null   object
#  12  Revenue            8690 non-null   object
#  13  Competitors        8690 non-null   object
#  14  Easy Apply         8690 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ MB

# %%
data[data['Company Name'].isna()]
# Out:
#          Job Title             Salary Estimate  \
# 1860  Data Analyst  $53K-$99K (Glassdoor est.)
#
#                                         Job Description  Rating Company Name  \
# 1860  Kindred at Home, part of the Kindred at Home f...    -1.0          NaN
#
#              Location Headquarters Size  Founded Type of ownership Industry  \
# 1860  Mooresville, NC           -1   -1       -1                -1       -1
#
#      Sector Revenue Competitors Easy Apply
# 1860     -1      -1          -1         -1

# %%
data = data.dropna()

# %%
data[data['Company Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply]
# Index: []

# %% [markdown]
# ### Job titles

# %% [markdown]
# ##### Which positions have the most openings?

# %%
from collections import Counter
job_counts = Counter(data['Job Title'])

# %%
top_jobs = job_counts.most_common(10)

# %%
def plot_data_dict(title, counter):
    plt.figure()
    plt.barh(
        y=[item[0] for item in counter],
        width=[item[1] for item in counter])
    plt.title(title)
    plt.show()

# %%
plot_data_dict('Job openings by profession', top_jobs)

# %% [markdown]
# ##### Which sector has the most jobs available?

# %%
# A lot of rows had a -1 as sector, which probably stands for N/A
sector_count = Counter(data[data['Sector'] != '-1'].Sector)
top_secs = sector_count.most_common(10)

# %%
plot_data_dict('Openings by job sector', top_secs)

# %% [markdown]
# ##### Which companies are posting the most jobs?

# %%
company_count = Counter(data['Company Name'])
top_co = company_count.most_common(10)

# %%
plot_data_dict('Openings by company name', top_co)

# %% [markdown]
# ### Salary

# %% [markdown]
# ##### Computing the average salary

# %%
data['Salary Estimate']
# Out:
# 0        $37K-$66K (Glassdoor est.)
# 1        $37K-$66K (Glassdoor est.)
# 2        $37K-$66K (Glassdoor est.)
# 3        $37K-$66K (Glassdoor est.)
# 4        $37K-$66K (Glassdoor est.)
#                    ...
# 3904    $55K-$112K (Glassdoor est.)
# 3905    $55K-$112K (Glassdoor est.)
# 3906    $55K-$112K (Glassdoor est.)
# 3907    $55K-$112K (Glassdoor est.)
# 3908    $55K-$112K (Glassdoor est.)
# Name: Salary Estimate, Length: 8689, dtype: object

# %%
def get_salary_pos(est, var):
    """ Return the minimum or maximum salary estimation, depending on the 
    
    @param pd.Series est: The Salary Estimate DataFrame column
    @param str var: 'max' or 'min'
    @rtype: func
    """
    assert var in ['max', 'min']
    pos = {'min': 0, 'max': 1}[var]
    clean_estimate_string = est.replace('(Glassdoor est.)', '').replace('(Employer est.)', '').replace('$', '').replace('K', '')
    estimate = clean_estimate_string.split('-')[pos]
    if 'Per Hour' in estimate: # fix hourly rate salaries
        return (int(estimate.replace('Per Hour', '')) * 52 * 40) / 1000
    return int(estimate)

# %%
data[data['Salary Estimate'] == '-1'] # This row was causing trouble below, dropping
# Out:
#                                       Job Title Salary Estimate  \
# 2149  Configuration/Data Management Analyst III              -1
#
#                                         Job Description  Rating  \
# 2149  Job Description\nPosition Title: Configuration...     4.4
#
#          Company Name  Location  Headquarters                 Size  Founded  \
# 2149  Protingent\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees     2001
#
#       Type of ownership                Industry             Sector  \
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply
# 2149  $25 to $50 million (USD)          -1         -1

# %%
data = data.drop([data.index[2148]])

# %%
data[data['Salary Estimate'] == '-1'] # This row was causing trouble below, dropping
# Out:
# Empty DataFrame
# Columns: [Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply]
# Index: []

# %%
data['Min. Salary Est.'] = data['Salary Estimate'].map(lambda est: get_salary_pos(est, 'min'))
data['Max. Salary Est.'] = data['Salary Estimate'].map(lambda est: get_salary_pos(est, 'max'))

# %%
data['Avg. Salary Est.'] = data['Salary Estimate'].map(lambda est: (get_salary_pos(est, 'min') + get_salary_pos(est, 'max')) / 2)

# %%
data[['Min. Salary Est.', 'Avg. Salary Est.', 'Max. Salary Est.']].head()
# Out:
#    Min. Salary Est.  Avg. Salary Est.  Max. Salary Est.
# 0                37              51.5              66.0
# 1                37              51.5              66.0
# 2                37              51.5              66.0
# 3                37              51.5              66.0
# 4                37              51.5              66.0

# %%
sns.distplot(data['Avg. Salary Est.'])
plt.title("Distribution of average salary estimations")
plt.show()

# %%
sns.distplot(data[data['Avg. Salary Est.'] < 150]['Avg. Salary Est.'])
plt.title("Distribution of average salary estimations below $150K")
plt.show()

# %% [markdown]
# ##### Salary by profession

# %%
engineers = data[data['Job Title'].map(lambda title: 'Data Engineer' in title)]
analysts = data[data['Job Title'].map(lambda title: 'Data Analyst' in title)]
scientists = data[data['Job Title'].map(lambda title: 'Data Scientist' in title)]

# %%
sns.distplot(engineers['Avg. Salary Est.'], label="Data Engineers")
sns.distplot(analysts['Avg. Salary Est.'], label="Data Analysts")
sns.distplot(scientists['Avg. Salary Est.'], label="Data Scientists")
plt.legend()
plt.show()

# %% [markdown]
# ##### Salary by sector

# %%
# reuse the sector count variable from above
top_5 = sector_count.most_common(5)
for sector in top_5:
    sector_data = data[data['Sector'] == sector[0]]
    sns.distplot(sector_data['Avg. Salary Est.'], label=sector)
plt.legend()
plt.show()

# %% [markdown]
# ### Overall satisfaction

# %%
data['Rating']
# Out:
# 0       3.2
# 1       3.8
# 2       3.4
# 3       4.1
# 4       3.9
#        ...
# 3904    4.4
# 3905    5.0
# 3906    3.8
# 3907    4.0
# 3908    3.7
# Name: Rating, Length: 8686, dtype: float64

# %%
data[data['Rating'] == -1].shape[0]
# Out:
# 914

# %%
plt.figure()
sns.boxplot(data[data['Rating'] > -1].Rating)
plt.show()

# %% [markdown]
# ### Location

# %% [markdown]
# ##### Which states have the most openings?

# %%
count_loc = Counter(data.Location)
top_20 = count_loc.most_common(20)

# %%
plot_data_dict('Job openings by city', top_20)

# %%
data['State']=data['Location'].map(lambda loc: loc.split(',')[1].strip())

# %%
count_states = Counter(data.State)
top_10 = count_states.most_common(10)

# %%
plot_data_dict('Job openings by state', top_10)

# %%
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# %%
jobs_by_state = pd.DataFrame()

# %%
jobs_by_state['State'] = pd.Series([item[0] for item in count_states.items()])
jobs_by_state['Jobs'] = pd.Series([item[1] for item in count_states.items()])

# %%
jobs_by_state = jobs_by_state.drop([jobs_by_state.index[20], jobs_by_state.index[19]])
jobs_by_state
# Out:
#    State  Jobs
# 0     NY   845
# 1     NJ   142
# 2     UT    33
# 3     CA  2294
# 4     VA    48
# 5     FL   224
# 6     IL   727
# 7     TX  2646
# 8     AZ   592
# 9     PA   611
# 10    DE    37
# 11    OH   212
# 12    NC    89
# 13    SC     3
# 14    IN    23
# 15    WA    53
# 16    GA     4
# 17    KS     3
# 18    CO    88

# %%
max_amount = jobs_by_state.Jobs.max()
hmap = folium.Map(location=[45, -77], zoom_start=4)
hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
states_coords = pd.read_csv(path+'states_coord.csv')
states_coords.head()
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California

# %%
def get_state_coords(state, df):
    row = df[df['state'] == state]
    return (row.latitude.to_numpy()[0], row.longitude.to_numpy()[0])

# %%
jobs_by_state['Latitude']=jobs_by_state['State'].map(lambda state: get_state_coords(state, states_coords)[0])
jobs_by_state['Longitude']=jobs_by_state['State'].map(lambda state: get_state_coords(state, states_coords)[1])

# %%
jobs_by_state
# Out:
#    State  Jobs   Latitude   Longitude
# 0     NY   845  43.299428  -74.217933
# 1     NJ   142  40.058324  -74.405661
# 2     UT    33  39.320980 -111.093731
# 3     CA  2294  36.778261 -119.417932
# 4     VA    48  37.431573  -78.656894
# 5     FL   224  27.664827  -81.515754
# 6     IL   727  40.633125  -89.398528
# 7     TX  2646  31.968599  -99.901813
# 8     AZ   592  34.048928 -111.093731
# 9     PA   611  41.203322  -77.194525
# 10    DE    37  38.910832  -75.527670
# 11    OH   212  40.417287  -82.907123
# 12    NC    89  35.759573  -79.019300
# 13    SC     3  33.836081  -81.163725
# 14    IN    23  40.551217  -85.602364
# 15    WA    53  47.751074 -120.740139
# 16    GA     4  32.157435  -82.907123
# 17    KS     3  39.011902  -98.484246
# 18    CO    88  39.550051 -105.782067

# %%
jobs_by_state['Jobs']=jobs_by_state['Jobs'].map(lambda x: float(x))
jobs_by_state['Latitude']=jobs_by_state['Latitude'].map(lambda x: float(x))
jobs_by_state['Longitude']=jobs_by_state['Longitude'].map(lambda x: float(x))
jobs_by_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      19 non-null     object
#  1   Jobs       19 non-null     float64
#  2   Latitude   19 non-null     float64
#  3   Longitude  19 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 760.0+ bytes

# %%
geo_data = list(zip(jobs_by_state.Latitude.values, 
                    jobs_by_state.Longitude.values, 
                    jobs_by_state.Jobs.values))

# %%
hm_wide = HeatMap(geo_data,
                  min_opacity=0.5, max_val=float(max_amount), radius=17, blur=15, 
                  max_zoom=5)

# %%
hmap.add_child(hm_wide)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def check_top_salary_dist(state_list, df, top_n):
    for state in state_list[:top_n]:
        state_data = df[df['State'] == state[0]]
        sns.distplot(state_data['Avg. Salary Est.'], label=state)
    plt.legend()
    plt.xticks(list(range(0, 250, 20)))
    plt.show()

# %%
check_top_salary_dist(top_10, data, 3)

# %%
check_top_salary_dist(top_10, data, 5)

# %% [markdown]
# ### Skills and job description

# %% [markdown]
# ##### Required skills

# %%
descs = data['Job Description']

# %%
curated_list = [
    ('python', 'python2.7', 'python3'),
    ('sql', 'mysql', 'postgresql', 'mssql', 'oracle'), 
    ('nosql', 'mongodb', 'couchdb', 'orientdb'),
    ('r', 'rstudio'), 
    'hadoop', 
    ('spark', 'pyspark'),
    ('scikit-learn', 'sklearn'),
    'tensorflow', 
    'keras', 
    'pytorch',
    ('mapreduce', 'map-reduce')
]

# %%
def find_skills(desc, skill_count):
    """
    Check the job description for any of our curated skills.
    Everytime one of them appears in a job description, record it.
    
    @param str desc: the job description
    @param dict skill_count: an external variable keeping track of the skills
    @rtype: None
    """
    for skill in curated_list:
        if type(skill) == str:
            if skill in desc.lower().split():
                skill_count[skill] = skill_count.setdefault(skill, 0) + 1
        elif type(skill) == tuple:
            if any(filter(lambda syn: syn in desc.lower().split(), skill)):
                skill_count[skill[0]] = skill_count.setdefault(skill[0], 0) + 1
    return

# %%
skill_count = {}
descs.map(lambda desc: find_skills(desc, skill_count))

# Plot the results
data_points = sorted(skill_count.items())
plot_data_dict("Skills needed by job openings", data_points)

# %% [markdown]
# ##### What about the skills required for each position?

# %%
de_skill_count, da_skill_count, ds_skill_count = {}, {}, {}
labels = [item for item in curated_list if type(item) == str]\
        + [item[0] for item in curated_list if type(item) == tuple] 
for skill in labels:
    if type(skill) == str:
        de_skill_count[skill] = 0
        da_skill_count[skill] = 0
        ds_skill_count[skill] = 0
    else:
        de_skill_count[skill[0]] = 0
        da_skill_count[skill[0]] = 0
        ds_skill_count[skill[0]] = 0

# %%
_ = engineers['Job Description'].map(lambda desc: find_skills(desc, de_skill_count))
_ = analysts['Job Description'].map(lambda desc: find_skills(desc, da_skill_count))
_ = scientists['Job Description'].map(lambda desc: find_skills(desc, ds_skill_count))

# %%
def plot_stacked_bars(labels, width, title): 
    N = len(labels)
    da_data = tuple([item for item in da_skill_count.values()])
    de_data = tuple([item for item in de_skill_count.values()])
    ds_data = tuple([item for item in ds_skill_count.values()])

    ticks = np.arange(len(labels))

    da_plt = plt.bar(ticks, da_data, width)
    de_plt = plt.bar(ticks, de_data, width, bottom=da_data)
    ds_plt = plt.bar(ticks, ds_data, width, bottom=de_data)

    plt.ylabel('Number of occurences')
    plt.title(title)
    plt.xticks(ticks, labels, rotation=45)
    plt.legend((da_plt[0], de_plt[0], ds_plt[0]), ('Data Analysts', 'Data Engineers', 'Data Scientists'))

    plt.show()

# %%
plot_stacked_bars(labels, 0.7, 'Required skills by job title')

# %%
labels.remove('python')
labels.remove('sql')

# %%
da_skill_count.pop('python')
de_skill_count.pop('python')
ds_skill_count.pop('python')
# Out:
# 382

# %%
da_skill_count.pop('sql')
de_skill_count.pop('sql')
ds_skill_count.pop('sql')
# Out:
# 330

# %%
plot_stacked_bars(labels, 0.7, 'Required skills by job title - excluding Python & SQL')

# %% [markdown]
# ##### Job description topic modelling

# %%
import re
import nltk
from nltk.stem import PorterStemmer
import wordcloud

# %%
def preprocess_desc(desc):
    
    # remove special characters
    desc = re.sub(r'[^a-zA-Z\s]', '', desc, re.I|re.A)
    
    # convert to lower case
    desc = desc.lower()
    
    # strip trailing whitespace
    desc = desc.strip()
    
    # tokenize description
    tokenizer = nltk.WordPunctTokenizer()
    tokens = tokenizer.tokenize(desc)
    
    # remove stopwords
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [tok for tok in tokens if not tok in stop_words]
    
    # stem job description
    ps = PorterStemmer()
    tokens = [ps.stem(tok) for tok in tokens]
    
    # join the tokens back, separated by a space
    desc = ' '.join(tokens)
    return desc

# %%
desc_tokens = data['Job Description'].map(lambda desc: preprocess_desc(desc))

# %%
desc_tokens
# Out:
# 0       eager roll sleev har data drive polici chang e...
# 1       overview provid analyt technic support integr ...
# 2       look senior data analyst love mentorship data ...
# 3       requisit numberrr remotey collabor creat innov...
# 4       fanduel group fanduel group worldclass team br...
#                               ...
# 3904    us tachyon technolog digit transform consult f...
# 3905    job descript interpret data analyz result use ...
# 3906    job descriptionth secur analyt data engin inte...
# 3907    secur analyt data engin interfac secur big dat...
# 3908    help us transform patient live ucb put heart s...
# Name: Job Description, Length: 8686, dtype: object

# %%
import gensim
from gensim import corpora

# %%
list(desc_tokens)
# Out:
# ['eager roll sleev har data drive polici chang enjoy sift complex dataset illumin trend insight see work valuesdriven organ vision tackl press injustic day look hire bright hardwork creativ individu strong data manag skill demonstr commit immigr right data analyst assist analysi report need vera center immigr justic cij work across current project futur vera initi found vera institut independ nonpartisan nonprofit organ combin expertis research technic assist demonstr project assist leader govern civil societi examin justic polici practic improv system peopl reli justic safeti studi problem imped human digniti justic pilot solut transform achiev engag divers commun inform debat har power evid drive effect polici practic help build movementamong govern leader advoc immigr legal servic communitytoward univers legal represent immigr face deport face steppedup immigr enforc million noncitizen risk extend detent perman separ famili commun vera center immigr justic cij partner govern nonprofit partner commun improv govern system affect immigr famili cij administ sever nationwid legal servic program immigr face deport develop implement pilot program provid technic assist conduct independ research evalu that come data analyst support center programmat effort regular monitor report feder govern subcontractor data cij manag sever proprietari databas run aw caspio use sql r python manag data opportun help shape innov nation research polici agenda part dedic team expert work improv access justic noncitizen vera seek hire data analyst work variou data manag project center immigr justic cij collabor data analyst posit involv work across sever project unaccompani children program ucp program increas legal represent immigr children face deport without parent legal guardian posit may cover addit duti legal orient program custodian lopc educ custodian unaccompani children right immigr court process role data analyst report member research team work close collabor vera staff ongo databas manag monitor report analysi project youll support team take ownership ongo monitor report task involv larg data set princip respons includ support research staff prepar larg dataset analysi includ merg clean recod data provid insight program perform summari statist perform indic produc time report vera project team member stakehold improv recur report process optim code produc subsequ document coordin databas manag task particip new databas design modifi exist databas commun outsid engin subcontractor develop codebook deliv user train webinar databas guid build maintain interact dashboard document correct data qualiti issu work supervisor priorit program need assist project task assign your commit improv issu affect immigr unit state applic person experi immigr system especi encourag appli your get start career year profession internship experi work larg dataset prepar data analysi real enthusiasm work data comfort write queri sql r andor python solid foundat code program languag use manipul data experi work collabor use tool like gitgithub plu except attent detail strong problemsolv abil logic reason skill abil detect anomali data your abl work multipl project effect effici independ collabor team posit involv work secur data may requir govern secur clearanc clearanc restrict us citizen citizen countri parti collect defens agreement us list countri detail webpag addit requir clearanc resid unit state least three last five year appli pleas submit cover letter resum applic consid roll basi posit fill onlin submiss pdf format prefer applic cover letter attach consid cover letter address interest cij posit howev necessari materi may mail fax attn human resourc cij data analyst recruit vera institut justic th st suit brooklyn ny fax pleas use one method onlin mail fax submiss phone call pleas applic select interview contact vera equal opportunityaffirm action employ qualifi applic consid employ without unlaw discrimin base race color creed nation origin sex age disa ...
#  'overview provid analyt technic support integr multipl data sourc use prepar intern extern report qualiti manag team busi stakehold provid support analyt insight qualiti incent measur hedi measur qualiti improv initi monitor analyz commun qualiti perform relat benchmark collabor clinic oper team within qualiti manag well choic clinic oper busi intellig analyt bia particip data valid current report dashboard monitor data integr databas provid recommend accordingli particip develop intern dashboard databas work gener direct respons provid support analyt insight qualiti incent measur hedi measur qualiti improv initi monitor intern perform benchmark analysi particip identif develop manag monitor qualiti improv initi collabor educ staff make recommend area focu train assessor care manag base analysi perform trend research identifi technicaloper problem surround systemsappl communicatesref complex unresolv problem manag busi intellig analyt bia andor conduct ad hoc analys help identifi oper gap care draft present report public etc regard result analys commun result data analysi nontechn audienc particip priorit department goal base identif oper gap care particip establish data qualiti specif design coordin support integr data system analyz valid inform identifi make recommend report redesign platform report eg autom manual excel file use macro develop microstrategi dashboard replac manual updat excel dashboard move data storag excel access etc need train staff use newupd system relat topic assist qualiti manag team databas depart report conduct oper review analysi process procedur issu report find implement approv chang requir identifi recommend softwar need applic accomplish requir report retriev compil review ensur accuraci data databas research correct discrep need analyz data intern extern sourc identifi resolv data qualiti issu report gener work staff correct data entri error analyz data identifi trend reoccur problem statist signific find prepar reportssummari manag review act liaison qualiti manag choic clinic oper bia review identifi trend varianc data report research find determin appropri elev identifi issu leadership reviewevaluationact monitor maintain file ensur file current relev natur analyz correct error report ensur time accur data develop correct action prevent error possibl particip special project perform duti need qualif educ bachelor degre biostatist epidemiolog mathemat comput scienc social scienc relat field equival work experi requir master degre concentr comput scienc data scienc statist prefer experi minimum two year experi perform increasingli complex data analysi interpret prefer manag care health care set requir experi data extract manipul requir experi relat databas program experi sql plsql requir experi claim data health plan qualiti metric eg hedi qarr prefer profici conduct statist analysi r sa stata statist softwar prefer advanc person comput skill includ microsoft word powerpoint excel access requir effect oral written commun interperson skill requir abil multi task fastpac environ requir ca',
#  'look senior data analyst love mentorship data visual gener action insight raw data role youll opportun organiz influenc gener insight good degre autonomi partner data scienc grow deeper analyt skill join insight analyt team team task develop insight report support custom advisor need team sit within custom oper team also connect product organ role work mainli custom oper stakehold set kpi evalu effect current strategi workflow involv mani aspect data oper data audit build dashboard analyt insight exampl review code junior analyst organ code workshop build metric evalu perform advisor elimin confound variabl creat weight measur account individu success defin metric creat dashboard track success current strateg direct analyz textbas interact advisor improv care qualiti also analyz interact chatbot improv respons bot match custom expect collabor data engin team pursuit better data model collabor data scienc team modelingheavi pursuit like topic model search recommend mentor member analyt team demand excel cultur teach learn report manag insight analyt team custom oper squarespac new york offic respons design develop kpi report dashboard use bidata visual tool clearli track effect current strategi execut commun impact analys use sql rpython improv custom experi drive custom oper product roadmap rais skill level analyt team review code organ train session act mentor introduc new analyt method tool help design evalu experi pilot set clear hypothes success metric well use right statist method analys effect partner custom oper product stakehold well data engin team qualif year experi data analyst data scientist relev field work larg dataset transform data meaning insight masteri sql experi rpython experi dashboardingbi tool like chartio looker tableau experi data clean analysi present nontechn stakehold bachelor degre quantit logicdriven disciplin intellectu curios deep love mentorship gener action insight prefer advanc degre master phd quantit field prefer experi topic model text analyticsnatur languag process hire variou experi level particularli interest divers team broad set skill viewpoint seem like opportun youd like explor your sure qualifi encourag appli anyway squarespac squarespac make beauti product help peopl creativ idea succeed blend eleg design sophist engin empow million peopl individu local artist entrepreneur shape world icon busi share stori world squarespac team headquart downtown new york citi offic dublin portland inform visit wwwsquarespacecomabout today million peopl around globe use squarespac share differ perspect experi world embrac celebr divers custom base also strive employe squarespac commit equal employ opportun regardless race color ancestri religion sex nation origin sexual orient age citizenship marit statu disabl gender gender ident express veteran statu proud equal opportun workplac',
#  'requisit numberrr remotey collabor creat innov intrigu your busi profession innat curios thrive dynam agil environ appreci teamwork exemplifi integr persever flexibl generos spirit sound like pleas appli wed love meet celer expand hunt savvi creativ analyt sound individu motiv solv complex problem busi transform peopl process system coexist improv oper effici userdriven interact work groundbreak compani meld expertis digit strategi technolog creativ busi transform health safeti employe top prioriti due pandem employe work remot conduct candid interview video posit continu remot covid crisi abat youll perform data visual comparison across multipl data sourc system record provid valuead insight support critic busi oper team build script perform lowlevel analysi data investig work conjunct celer client team member improv data accuraci make inform decis support movement larg amount data exist process new ecosystem includ look opportun greater autom exist process via sql produc custom report visual well adhoc analysi support timesensit busi request demonstr flexibl expand beyond pure data analysi role includ upstream requir gather downstream process recommendationsimplement center around strong understand client data bachelor degre busi manag quantit field year sql develop complex queri year profession experi expertis design implement etl process teradata sql experi prefer experi data visual tableau powerbi understand experi multidimension analysi queri strong commun skill analyt mindset abl ask probe question erad ambigu will point flaw logic identifi better way thing good data intuit order taker analyst sniff trend identifi pattern answer open end question willing expand scope work beyond data includ busi analyst process analyst project manag type activ necessari celer million peopl everi day use websit applic busi process design built celer consult technologist creativ busi expert provid action plan team solut client need trans
#  'requisit number post date titl data center servic analyst ii iii senior posit type full time compani alaska usa feder credit union locat glendal data center citi glendal state az minimum salari grade categori depend experi work hour monday friday pm regular schedul five hour day ye descript report vari locat function supervis none primari function senior data center servic analyst respons administ credit union enterpris product environ individu act gatekeep ensur maintain health integr product environ work stakehold deploy complex enterpris product solut core applic deploy mainten vmware citrix oper system upgrad secur standard control vulner manag duti respons data center servic iii duti respons provid project leadership complex multidisciplinari team support applic oper system deploy deploy upgrad complex enterpris applic oper system particip design deploy complex secur control standard assist research mitig complex secur vulner assist develop enterpris antiviru malwar dataloss prevent control develop complex script support department project initi maintain current profession technic knowledg pertain industri standard best practic field hour work oncal assign assist train data center servic analyst ii iii personnel perform duti assign requir educ bachelor degre comput scienc mathemat relat field credit experi lieu educ equival technic train andor work experi experienceskil eight year demonstr experi manag deploy enterpris system three year experi data center servic analyst iii equival experi andor train mcseaix unix advanc certif prefer must work knowledg hyperconverg infrastructur window oper system linux oper system clientserv network script languag tool excel commun interperson skill requir experi servicenow solarwind itil v certif pluss tenur assign data center servic analyst categori data center servic analyst ii categori data center servic analyst iii categori senior data center servic analyst categori determin candid educ experi advanc requir manag recommend base candid certif andor perform appli onlin send job friend copyright alaska usa ultrabranch regist trademark alaska usa feder credit union mortgag loan provid alaska usa mortgag compani llc licens ak washington consum loan compani licens cl licens depart busi oversight california residenti mortgag lend act licens instruct enter user id click log view person keypad enter pac initi user id member account number print topright corner statement problem forgot password pac forgot user id issu still question call learn learn ultrabranch secur comput stay uptod oper system patch comput phone tablet use current web browser instal updat instal antiviru antispywar softwar keep program updat protect never share person access code pac review account regularli contact member servic center question rememb alaska usa never call email text member request confidenti inform learn fraud ident theft phish',
#  'paragon group columbu ohio base inform technolog firm deliv high qualiti cost effect resourc progress clientel found paragon group full time staff highli skill motiv profession paragon group provid staff augment temptoperm placement perman placement consult servic local nation full time employ offer full benefit packag current look data analyst long term employ opportunitymust abl work w advanc sql skill work multipl db technolog like teradata oracl redshift etc profici profil skill use tool like idq would plu profici sourc target map skill moder data model relat dimension skill good commun skill necessari profession skill work agil line',
#  'acescentr flow seek data analyst nacf central data analyst team new team locat aza temp arizona support fulfil center across nacf success candid highli organ extrem detail selfmotiv abl handl confidenti inform well possess demonstr abil respond effect chang workload prioriti must abil commun well manag multipl assign peopl simultan respons includ configur request na fc launch team ace sme team run project relat central flow order improv process oper multipl fulfil center fc key area respons includ research analyz issu particip pilot fix bug partner fc build excel tool autom report icqa research includ irdr research deep dive success candid strong blend project manag skill abil conduct indepth analys think big identifi strateg opportun basic qualif high school diploma equival diploma year experi excel spreadsheet data analysi year experi creat vba code tool write year experi work sql demonstr fluenci prefer qualif year data analyst research analyst experi demonstr problem solv skill analyt skill proven abil clearli commun manag level global perspect solid understand busi object excel attent detail work highest level accuraci initi develop tool data collect process data manag system understand kibana toolset amazon commit divers inclus workplac amazon equal opportun employ discrimin basi race nation origin gender gender ident sexual orient protect veteran statu disabl age legal protect statu individu disabl would like request accommod pleas visit httpswwwamazonjobsendisabilityu',
#  'descriptionreport vari locationfunct supervis noneprimari function senior data center servic analyst respons administ credit union enterpris product environ individu act gatekeep ensur maintain health integr product environ work stakehold deploy complex enterpris product solut core applic deploy mainten vmware citrix oper system upgrad secur standard control vulner managementduti respons data center servic iii duti respons provid project leadership complex multidisciplinari team support applic oper system deploy deploy upgrad complex enterpris applic oper system particip design deploy complex secur control standard assist research mitig complex secur vulner assist develop enterpris antiviru malwar dataloss prevent control develop complex script support department project initi maintain current profession technic knowledg pertain industri standard best practic field hour work oncal assign assist train data center servic analyst ii iii personnel perform duti assignedrequirementseduc bachelor degre comput scienc mathemat relat fieldcredit experi lieu educ equival technic train andor work experienceexperienceskil eight year demonstr experi manag deploy enterpris system three year experi data center servic analyst iii equival experi andor train mcseaix unix advanc certif prefer must work knowledg hyperconverg infrastructur window oper system linux oper system clientserv network script languag tool excel commun interperson skill requir experi servicenow solarwind itil v certif plussestenur assign data center servic analyst categori data center servic analyst ii categori data center servic analyst iii categori senior data center servic analyst categori determin candid educ experi advanc requir manag recommend base candid certif andor performanceappli onlin send job friend',
#  'data analyst assign par work enterpris interact data strategi govern team serv team coordin design implement enterpris interact data strategi govern design knowledg includ limit understand custom data data structur data architectur busi rule util custom manag enterpris custom relationship manag agenc market insur affili auto fire life health bank mutual fund analyst skill respons partner variou busi user custom data servic expect broad understand specif process use access maintain data role coordin role requir excel commun skill must abl oper agil scrum team hand daytoday databas skillset abl use tool around hadoop solr hue etc occasion requir look immedi lift person eager jump right start work independ addit skill experi excel oral write commun skill commun govern data produc requir design intent variou busi partner across org experi prefer gather requir appli data strategi architectur design experi prefer insur financi servic oper busi process knowledg experi prefer analyt skill critic think databas knowledg experi prefer follow tool hadoop mongodb big dataai relat databas structur experi prefer member second third level technic servic support team experi prefer hp servic manag incid problem configur manag experi state farm data risk complianc process prefer compet strong verbal written commun skill great attitud team player bring innov team',
#  'net orbit inc open posit data analyst master degre comput scienc engin technolog relat yr exp design develop requir analyt project respons busi need perform data migrat task use sql hive queri legaci mainfram db big data hive impala similar enterpris rdbm analyz assess qualiti integr data develop implement data collect system strategi optim statist effici data qualiti respons applic develop use phase softwar develop life cycl sdlc includ analysi design develop work locat temp az requir travel client locat throughout usa pleas mail resum e broadway rd suit temp az email',
#  ...]

# %%
dtm = [corpora.Dictionary(list(desc_tokens)).doc2bow(desc) for desc in desc_tokens]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-427-03c9face0185> in <module>
# ----> 1 dtm = [corpora.Dictionary(list(desc_tokens)).doc2bow(desc) for desc in desc_tokens]
#
# <ipython-input-427-03c9face0185> in <listcomp>(.0)
# ----> 1 dtm = [corpora.Dictionary(list(desc_tokens)).doc2bow(desc) for desc in desc_tokens]
#
# /opt/anaconda3/lib/python3.7/site-packages/gensim/corpora/dictionary.py in __init__(self, documents, prune_at)
#      89
#      90         if documents is not None:
# ---> 91             self.add_documents(documents, prune_at=prune_at)
#      92
#      93     def __getitem__(self, tokenid):
#
# /opt/anaconda3/lib/python3.7/site-packages/gensim/corpora/dictionary.py in add_documents(self, documents, prune_at)
#     210
#     211             # update Dictionary with the document
# --> 212             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     213
#     214         logger.info(
#
# /opt/anaconda3/lib/python3.7/site-packages/gensim/corpora/dictionary.py in doc2bow(self, document, allow_update, return_missing)
#     250         """
#     251         if isinstance(document, string_types):
# --> 252             raise TypeError("doc2bow expects an array of unicode tokens on input, not a single string")
#     253
#     254         # Construct (word, frequency) mapping.
#
# TypeError: doc2bow expects an array of unicode tokens on input, not a single string
